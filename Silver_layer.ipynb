# %%
dbutils.widgets.text('source','netflix_cast');
dbutils.widgets.text('target','netflix_cast');
source_folder=dbutils.widgets.get('source');
target_folder=dbutils.widgets.get('target');
print(source_folder)

# %%
data=spark.read.format('csv').option('header','true').load(f'abfss://bronze@pronetflixdata.dfs.core.windows.net/{source_folder}')

# %%
data.show(10);

# %%
data.write.format('delta').mode('append').save(f'abfss://silver@pronetflixdata.dfs.core.windows.net/{target_folder}')
