# %%
# create schema netflix_catalog.net_schema

# %% [markdown]
# check point the location in a variable.

# %%
checkpoint_loc='abfss://silver@pronetflixdata.dfs.core.windows.net/checkpoints'

# %% [markdown]
# # Read Stream using Autoloader

# %%
data=spark.readStream.format('cloudFiles') \
    .option('cloudFiles.format','csv') \
        .option('cloudFiles.schemaLocation',checkpoint_loc) \
            .load('abfss://raw@pronetflixdata.dfs.core.windows.net')

# %%
# display(data)

# %% [markdown]
# # Writing the netflix_titles data incrementally  to the silver layer using autoloader

# %%
# data.writeStream.option('checkpointLocation',checkpoint_loc) \
   # .trigger(once=True) \
    #    .start('abfss://silver@pronetflixdata.dfs.core.windows.net/netflix_titles')
