# %%
files=[

{


"source":"netflix_cast",
"target":"netflix_cast"

},

{
    "source":"netflix_directors",
    "target":"netflix_directors"
},

{

"source":"netflix_countries",
"target":"netflix_countries"

},

{

    "source":"netflix_category",
    "target":"netflix_category"

}

]

# %%
dbutils.jobs.taskValues.set(key="list", value=files)
